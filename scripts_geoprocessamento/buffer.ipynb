# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 15.4 MB 31.7 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 41.7 MB/s
# ...

# %%
import geopandas as gpd

# %%
lago_paranoa_utm_23s = gpd.read_file ('/content/drive/MyDrive/sig/lagoparanoa.shp')

# %%
buffer = lago_paranoa_utm_23s.buffer(distance=30, resolution=16)

# %%
buffer.plot(figsize=(14,12));

# %%
plt.
