# %%
# !pip install spectral
# !pip install numpy
# !pip install tiffile
# Out:
# ...
#      |████████████████████████████████| 212 kB 5.2 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from spectral import *
import numpy as np
import tifffile as tif
import matplotlib.pyplot as plt

# %%
img = ('/content/drive/MyDrive/CBERS 4A/CBERS4A_FLONABSB.tif')

# %%
img = tif.imread('/content/drive/MyDrive/CBERS 4A/CBERS4A_FLONABSB.tif')

# %%
(classif, centro) = kmeans(img, 8, 30)
# Out:
# spectral:INFO: k-means iteration 1 - 1279499 pixels reassigned.
# spectral:INFO: k-means iteration 2 - 195001 pixels reassigned.
# spectral:INFO: k-means iteration 3 - 124565 pixels reassigned.
# spectral:INFO: k-means iteration 4 - 62340 pixels reassigned.
# spectral:INFO: k-means iteration 5 - 36758 pixels reassigned.
# spectral:INFO: k-means iteration 6 - 30702 pixels reassigned.
# spectral:INFO: k-means iteration 7 - 32734 pixels reassigned.
# spectral:INFO: k-means iteration 8 - 35436 pixels reassigned.
# spectral:INFO: k-means iteration 9 - 34840 pixels reassigned.
# spectral:INFO: k-means iteration 10 - 33673 pixels reassigned.
# spectral:INFO: k-means iteration 11 - 32905 pixels reassigned.
# spectral:INFO: k-means iteration 12 - 32687 pixels reassigned.
# spectral:INFO: k-means iteration 13 - 32493 pixels reassigned.
# spectral:INFO: k-means iteration 14 - 32752 pixels reassigned.
# spectral:INFO: k-means iteration 15 - 32691 pixels reassigned.
# ...

# %%
plt.imshow(classif, cmap='Spectral_r')

# %%
plt.figure()

# %%
for i in range(centro.shape[0]):
    plt.plot(centro[i])
plt.grid()
